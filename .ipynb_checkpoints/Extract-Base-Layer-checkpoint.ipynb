# %%
from bs4 import BeautifulSoup
print(BeautifulSoup.__doc__)
# Out:
#     This class defines the basic interface called by the tree builders.
#
#     These methods will be called by the parser:
#       reset()
#       feed(markup)
#
#     The tree builder may call these methods from its feed() implementation:
#       handle_starttag(name, attrs) # See note about return value
#       handle_endtag(name)
#       handle_data(data) # Appends to the current data node
#       endData(containerClass=NavigableString) # Ends the current data node
#
#     No matter how complicated the underlying parser is, you should be
#     able to build a tree using 'start tag' events, 'end tag' events,
#     'data' events, and "done with data" events.
#
#     If you encounter an empty-element tag (aka a self-closing tag,
#     like HTML's <br> tag), call handle_starttag and then
#     handle_endtag.

# %%
import glob
#function 

def get_fields_from_bs(bs_object, field_dict):
    """This function takes a dictionary of fields, with bs.find arguments as values,
       and/or findall, and returns a dictionary of those fields   
    """
    row = {}
    for u in fields.keys():
        try:
            field_data = x.find(fields[u]).text
        #respond if it errors or is empty
        except:
            field_data = ''
        #parse field if needed ... with conditionals
        row[u] = field_data
    return row

def base_layer_maker(location, collection_type):
    """This function accepts two arguments and writes data to base-layers
       Location should be a folder name only that can be found in source-data, such as 'american-left-ephemera'
       Collection is a controlled vocabulary ('archive', 'serial', 'monograph')
       Errors if you pass anything else
    """
    #create subdirectory in base-layers for that location
    newdir = "base-layers" + location
    
    try:
        os.stat(newdir)
    except:
        os.mkdir(newdir)
    
    #all mods in folder
    items_data = []
    _dir = "source-data/%s/mods/" % location
    mods_files = glob.glob(_dir+'*.xml')
    for z in mods_files: 
        with open(z) as f:
            data = f.read()
            items_data.append(data)
    
    #soup the files      
    items_bs = [BeautifulSoup(x) for x in items_data]
    #get fields from each item record, make csv (add to this)
    output_rows = {}
    
    #make a datastore of fields you want ... change for collection type
    
    ##
    ##
    ##
    # customize here
    ##
    ##
    ##
    
    fields = {'title':'mods:title', 'identifier': ['mods:identifier', {'type':'pitt'}]}
    #loop fields and get
    for x in items_bs:
        row = get_fields_from_bs(x, fields)
        #create keys if they don't exist
        for key in rows.keys():
            try:
                #if they do exist, append values from row
                output_rows[key].append(row[key])
            except:
                #if not, create and add first value as item in list
                output_rows[key] = [row[key],]
        #convert output_rows to pandas dataframe and use to_csv()
    #use collection_type to open files
    if collection_type == 'archive':
        _dir = "source-data/%s/ead/" % location
        ead_files = glob.glob(_dir+'*.xml')
        #find only xml in that location
        with open(ead_files[0]) as f:
            ead_data = f.read()
        
        ead_fields = {}
        #make bs object
        ead_bs = BeautifulSoup(ead_data)
        #get fields from ead, make yaml
        row = get_fields_from_bs(ead_bs, ead_fields)
        
        #write row to yaml file
        
    if collection_type == 'serial' or collection_type == 'monograph':
        pass
        #use if needed
    return True
        
            
#function call example
result = base_layer_maker('american-left-ephemera', 'archive')
# Out:
# title "Democracy Should Begin At Home"
# identifier 31735061656561

# %%
#TO DO
        
#feed it a location, and a kind of collections data ... DONE
#it writes files, returns True at the end ... DONE
#where to get the info changes, columns change ... DONE

#metadata.yaml
## for archival ... ead, mods to yaml
## for a monograph collection, every marc in the folder (write an empty yaml with one field for "description")
## for archival collections, put series.csv yaml? 
## for series? Need to finish base layer

#csv items
## for archival, items.csv
#### columns: 
## for monographs, items.csv
#### columns:
## for serials, items.csv
#### columns:

#csv columns are the base data layer items for that kind ... See Base Data Layer Config on Google Drive
#finish and push

# %%
#example code 
#_dir = "source-data/american-left-ephemera/ead/pitt_US-PPiU-ais200711_EAD.xml"
#with open(_dir) as f:
    #ead = f.read()
_dir = "source-data/american-left-ephemera/mods/pitt_31735051654956_MODS.xml"
with open(_dir) as f:
    mods = f.read()

# %%
mods_bs = bs4.BeautifulSoup(mods)

# %%
title = mods_bs.find('mods:title')
identifier = mods_bs.find('mods:identifier', {'type':'pitt'}).text

#<mods:identifier type="pitt">31735051654956</mods:identifier>
# Out:
# '31735051654956'

# %%
ead[:1000]
# Out:
# '<mods:mods xmlns:ns2="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.loc.gov/mods/v3" xsi:schemaLocation="http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-3.xsd http://www.cdlib.org/inside/diglib/copyrightMD http://www.cdlib.org/groups/rmg/docs/copyrightMD.xsd">\n  <mods:titleInfo>\n    <mods:title>"Resistance At Penn" Flyer,</mods:title>\n  </mods:titleInfo>\n  <mods:name>\n    <mods:namePart>University of Pittsburgh</mods:namePart>\n    <mods:role>\n      <mods:roleTerm type="text">depositor</mods:roleTerm>\n    </mods:role>\n  </mods:name>\n  <mods:typeOfResource>text</mods:typeOfResource>\n  <mods:genre>archival document</mods:genre>\n  <mods:originInfo>\n    <mods:dateOther type="display">April 11 1967</mods:dateOther>\n    <mods:dateCreated keyDate="yes" encoding="iso8601">1967-04-11</mods:dateCreated>\n    <mods:dateOther type="sort">19'

# %%
container = ead_bs.find('mods:note', {'type':'container'})

# %%
container_str = container.text
box = container_str.split(",")[0].replace("Box ", "")
folder = container_str.split(",")[1].replace("Folder ", "")

# %%
#title author split (experiment)
import os
_mods_dir = "source-data/american-left-ephemera/mods/"
results = []
for dirName, subdirList, fileList in os.walk(_mods_dir):
    for f in fileList:
        with open(dirName+f) as mf:
            xml = mf.read()
            bs = BeautifulSoup(xml, 'xml')
            title_author = bs.find('title')
            try:
                container = bs.find('note', {'type':'container'})
                container_str = container.text
                box = container_str.split(",")[0].replace("Box ", "")
                folder = container_str.split(",")[1].replace("Folder ", "")
            except:
                print(f)
            try: 
                results.append(title_author.text)
            except:
                print(dirName+f)
# Out:
# pitt_31735065151247_MODS.xml
# pitt_31735067913180_MODS.xml
# pitt_31735068355142_MODS.xml
# pitt_31735068354921_MODS.xml
# pitt_31735067911333_MODS.xml
# pitt_31735065150975_MODS.xml
# pitt_31735068355134_MODS.xml
# pitt_31735065151056_MODS.xml
# pitt_31735067913164_MODS.xml
# pitt_31735065150397_MODS.xml
# pitt_31735065150892_MODS.xml
# pitt_31735065151205_MODS.xml
# pitt_31735067911499_MODS.xml
# pitt_31735065150157_MODS.xml
# pitt_31735068354822_MODS.xml
# pitt_31735065150330_MODS.xml
# pitt_31735068354962_MODS.xml
# pitt_31735065150017_MODS.xml
# pitt_196504.1.2.002_MODS.xml
# pitt_196504.1.2.003_MODS.xml
# pitt_31735068355100_MODS.xml
# pitt_31735065150207_MODS.xml
# pitt_31735067913248_MODS.xml
# pitt_31735065151015_MODS.xml
# pitt_31735068354855_MODS.xml
# pitt_31735067911325_MODS.xml
# pitt_31735067913222_MODS.xml
# pitt_31735067911416_MODS.xml
# pitt_31735067911556_MODS.xml
# pitt_31735065151148_MODS.xml
# pitt_31735065151197_MODS.xml
# pitt_31735067911465_MODS.xml
# pitt_31735065150256_MODS.xml

# %%
results[0:10]
# Out:
# ['"Democracy Should Begin At Home"',
#  '"Delegate, Special Convention Communist Party, U.S.A., July 4-7, 1968"',
#  'Tenement Children Protest, New York City,',
#  'Mine-Mill union',
#  '"What Are You Doing About Your Undeclared War?" Flyer and Event Details,',
#  'Student Peace Union Recruitment Brochure',
#  'What is the New Deal?, by Earl Browder',
#  '"The Real Huey P. Long", By Sender Garlin,',
#  'Letter from Dr. Martin Luther King, Jr.,',
#  '"The Socialization of Money", By E.F. Mylius']

# %%
split = []
for r in results:
    if ", by " in r.lower():
        two_fields = r.split(", by ")
        if len(two_fields) == 1:
            two_fields = r.split(", By ")
        split.append(two_fields)
    else:
        split.append([r, ''])

# %%
[u[0] for u in split[0:200]]
# Out:
# ['"Democracy Should Begin At Home"',
#  '"Delegate, Special Convention Communist Party, U.S.A., July 4-7, 1968"',
#  'Tenement Children Protest, New York City,',
#  'Mine-Mill union',
#  '"What Are You Doing About Your Undeclared War?" Flyer and Event Details,',
#  'Student Peace Union Recruitment Brochure',
#  'What is the New Deal?',
#  '"The Real Huey P. Long"',
#  'Letter from Dr. Martin Luther King, Jr.,',
#  '"The Socialization of Money"',
#  'Wrecking the Labor Banks',
#  'War and the 4th International,',
#  '"Capitalism, Socialism, Communism?- A Debate"',
#  'Drum: Wildcat Strike,',
#  'The International Socialist Review,',
#  'Mine-Mill union',
#  '"World-Wide Unemployment", 20,000,000 Unemployed',
#  'Women of Yesterday and Today',
#  'The Position of Negro Women',
#  'May Day,',
#  '"Children Under Capitalism"',
#  '"In Flanders Field..."',
#  '"The Red Baiting Racket and How it Works"',
#  '"Smash Hitler\'s Spring Offensive Now!"',
#  'Coming! W.E.B. DuBois',
#  'Free Billy Smith',
#  '"Five Years of Hitler"',
#  'A Statement to the President, the Congress, and the People of the United States from the American Congress for Peace and Democracy,',
#  '"Haiti Faces Tomorrow\'s Peace"',
#  '"William Z. Foster, An Appreciation"',
#  '"No More Three Mile Islands U.S. Out of El Salvador" Flyer,',
#  '"The Path to Peace, Progress and Prosperity"',
#  'Greet the New Year with the L.A. Committee for Protection of Foreign Born',
#  'New Aspects of Imperialism (2)',
#  '"Realignment", One Year After the Party Convention',
#  'Mine-Mill union',
#  '"Labor and Anti- Semitism"',
#  'Justice For All Humanity, Colored America Answers the Challenge of Pearl S. Buck',
#  '"The Fascist Revival...the Inside Story of the John Birch Society...Who is in it? Who is Behind it? Who Directs and Finances it?"',
#  'LC News Letter Vol. 2, No. 4,',
#  '"How to Research Your Own Hometown"',
#  'Washington D.C. Protest Flyer,',
#  '"For a Turn Toward Peace" Petition/Flyer,',
#  '"A Plan for America", Official Campaign Handbook of the Socialist Party,',
#  '"Resolutions from the American Negro Leadership Conference on Africa",',
#  'Union',
#  '"Think or Surrender"',
#  'Military "Glory" in the Colleges',
#  'Union',
#  'Alternative, V2. N3,',
#  'Mother Earth, Vol. XI No. 4,',
#  "Sister: New Haven Women's Liberation Newsletter V.1, N.7",
#  '"Marxism and Culture No. I", A Brief Bibliography of Marxism and the Arts, Edited by Louis Harp',
#  '"Parade and Demonstrate" Flyer',
#  '"Whoever You Are...Wherever You Live" Flyer',
#  'The Negro People in the struggle for Peace and Freedom',
#  'A Socialist Labor Party Envelope and Ticket',
#  '"The Cruise Missile"',
#  '...and now Laos,',
#  '"An Open Letter to J. Howard McGrath", Attorney General of the United States,',
#  'Mine-Mill union',
#  'Various loose memorabilia',
#  'A Female Communist Demonstrator,',
#  '"Support the People\'s Cause..."',
#  'An Open Letter to President Kennedy,',
#  'Mine-Mill union',
#  'The Communists and the Liberation of Europe',
#  'Little Brothers of the Big Labor Fakers',
#  '"Value, Price and Profit"',
#  'A Scene in Phoenix when Naff was Leader of Movement,',
#  '"How Can We Share the Wealth?", The Communist Way Versus Huey Long',
#  '"Your Vote Can Stop the War in Korea Now!" Pamphlet',
#  'The Truth About Columbia Tennessee Cases',
#  '"Problems of Peace" Flyer',
#  '"We Propose this Program of Peace and Abundance for the People of North Carolina" Pamphlet,',
#  'Why We Defend the Soviet Union',
#  'People Against Rizzo Newsletter,',
#  'On the Struggle for Peace and Freedom',
#  '"Pattern for American Fascism"',
#  '"The Program of Class Struggle Co-operation" Pamphlet,',
#  '"Peace or War, The People against the Warmakers!"',
#  '"From Reform to Bayonets"',
#  '"Sit-Down"',
#  '"Le Front Populaire C\'est la Guerre",',
#  'Mine-Mill union',
#  'Women for Peace Letter,',
#  '"Synthesis is our Only Possibility"',
#  'Appeal to Reason Promotional Letter',
#  'A "Comrade" During the Arizona Disorders,',
#  'Red Tape and Barbed Wire',
#  'Anti-War Protestor',
#  'Are There Classes in America?',
#  'Mine-Mill union',
#  '"Wages in Mexican Money"',
#  '"The Menace of a New World War"',
#  'New Theatre,',
#  '"The Year of Great Decision, 1942"',
#  'Mine-Mill union',
#  '"Everything for Unity and Victory"',
#  '"Women of New York, WPA Cuts Threaten Your Standard of Living" Flyer',
#  '"Stock Ownership and the Control of Corporations"',
#  'Negro History Week,',
#  'SPU Program Statement',
#  '"Constitution of the Communist Political Association"',
#  'Rustin, McReynolds, and Barton Lecture Flyer,',
#  'The Kodak Worker, V.1, N. 8,',
#  '"Intellectuals and the War"',
#  '"Vote for John Makowski", Communist Candidate for Council- Ward 21',
#  '"The Menace of Opportunism"',
#  '"Is Communism Un-American?", 9 Questions About the Communist Party Answered',
#  'Flyer to Vote for Henry Steinberg',
#  '"Dust Off Your Dreams", The Story of American Youth for Democracy',
#  '"Nazis Preferred", The Renazification of Western Germany',
#  'Communist Rioters in Cleveland, Ohio,',
#  'Anti-Soviet Sabotage Exposed',
#  '"Don\'t Hurt Those Children in Vietnam" Protest',
#  '"Basis of Unity for the Campus Anti-Imperialist Coalition"',
#  'In Defense of Negro Rights',
#  '"Tom Mooney" Files',
#  '"What Makes Latin America Explosive" Flyer',
#  '"The Chicanos",',
#  'A Call for a Petition Campaign and Youth March',
#  '"Democracy in Danger"',
#  'Student Peace Union Bulletin,',
#  'Mine-Mill union',
#  'Mine-Mill union',
#  'Grand March Festival Given By The Socialists of St. Paul, Minn. at Germania Turner Hall,',
#  'Army Education Center Postcard,',
#  '"Religion and Communism"',
#  '"Policy Statement" from Washington D.C. Protest',
#  'A Socialist Party of America Membership Card',
#  '3 Worker\'s World Party Pamphlets Stating "People\'s Needs, Yes! Profits and War, No!"',
#  'Union',
#  '"Karl Marx, The Man and His Work and the Constructive Elements of Socialism", Three Lectures and Two Essays By Karl Dannenberg,',
#  '"The Big Tax Swindle and How to Stop It", An Analysis and Program for Action,',
#  'Mine-Mill union',
#  'Union',
#  'Mine-Mill union',
#  'Mine-Mill union',
#  '"A Public Forum for the Discussion of the Socialist Workers Party Program" Leaflet,',
#  '"The Pacifist Ethic and Humanism" Pamphlet,',
#  'Flyer advertising a demonstration referred to as the "Mass Funeral"',
#  'Mine-Mill union',
#  'YCL Pacesetter,',
#  'Union-Smashing in Sacramento, The Truth About the Criminal Syndicalism Trial',
#  '"Adopt Arnoni\'s Vietnam Proposal!" Propaganda Sheet,',
#  'The Two Souls Of Socialism',
#  'Jim Crow "Justice" In Korea, The Case of Lieutenant Leon Gilbert',
#  '"The ABC of Socialism"',
#  '"To Secure Justice in the Rosenberg Case" Pamphlet,',
#  '$222 Billion Dollars',
#  'The Monroe Kidnapping Newsletter,',
#  'Atlantic City Convention June 20 to 27, 1928',
#  'Atlantic City Convention June 9-16-1926',
#  '"The Way We See It" Pamphlet,',
#  '"Somebody Had to Say \'the emperor wears no clothes\'"',
#  'The Class Mark,',
#  'Labor Unity, What AFL-CIO Merger Means for Workers',
#  'Africa Fights for Freedom',
#  '"The Decline of American Radicalism in the Twentieth Century"',
#  'Exhibit of Soviet Literature Shown Before the DIES Committee,',
#  'Mine-Mill union',
#  'Photograph of a Man Observing a Guarded Wall of Leftist Leaflets',
#  'Mine-Mill union',
#  '"Students Take A Stand", An Account of Student Conferences in Washington During Christmas Week, 1933',
#  'New York Regional Newsletter,',
#  '"Our Generation is in Danger"',
#  'The Road to Negro Liberation, Report to the Eighth Convention of the Communist Party of the U.S.A.',
#  'Next- A Labor Party!',
#  'Your Unions Your Future,',
#  '"Defend the Bill of Rights Rally" Flyer',
#  'Outcry from Occupied Berkeley',
#  'Halt the Railroad Wage Cut',
#  '"America of the Rich',
#  'The USSR and Finland, Historical, Economic, Political Facts and Documents,',
#  '"A Dangerous Woman", Stella Petrosky Held for Deportation',
#  '"McCarthyism and the New Jersey Elections"',
#  '"Is This What Truman Means By Civil Rights!"',
#  'Send Nixon a Message Block Traffic Friday Morning',
#  '"What They Won\'t Tell You About Jobs and Prices", The Unemployment- Inflation Trap and the Way Out of It',
#  'The Struggle Against Imperialist War and the Tasks of the Communists, Resolution of the VI World Congress of the Communist International July-August, 1928,',
#  '"Science and Life"',
#  'The Irregular N. 3,',
#  '"A Call to Easter 1963 Student Peace Walk" Flyer,',
#  'A War Ship Can Be Stopped',
#  'Young Socialist, An Amateur Monthly Socialist Magazine (2),',
#  'Are We Aryans?',
#  'Front Cover of the Magazine Communist International,',
#  '"Constitution of the Communist Party of the United States of America",',
#  'La Wisp (3),',
#  'Partisan Review, Vol. 1 No. 2,',
#  'On Certain Aspects of Bourgeois Nationalism Pamphlet',
#  '"Appalachia U.S.A.", A Study in Poverty',
#  'Now is the Time',
#  'Women, War and Fascism',
#  '"Yiddish Short Stories",',
#  'Flyer for the Peace and Freedom Party Nominee for Lieutenant Governor, Clyde Kuhn,',
#  'Mine-Mill union',
#  'The Menace of American Imperialism',
#  '"The Youth Peace Corps and the Cold War" Memo,']
