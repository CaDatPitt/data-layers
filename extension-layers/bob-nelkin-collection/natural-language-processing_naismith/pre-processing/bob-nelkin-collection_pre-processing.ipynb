# %% [markdown]
# # Bob Nelkin Collection - Pre-processing
#
# <br>
#
# **Notebook author:** Ben Naismith
# **Last modified:** July 15, 2021
#
# <br>
#
# **Notebook contents:**
# 1. [Initial setup](#1.-Initial-setup)
# 2. [Combined dataframe](#2.-Combined-dataframe)
# 3. [Missing data](#3.-Missing-data)
# 4. [Standardization](#4.-Standardization)
# 5. [Save dataframe](#5.-Save-dataframe)

# %% [markdown]
# ## 1. Initial setup

# %%
# Import necessary modules

import pandas as pd
import pprint
from IPython.core.interactiveshell import InteractiveShell
import csv
import glob
from textblob import TextBlob
import PyPDF2
import pdfminer
import joblib

# %%
# Set preferred notebook format

InteractiveShell.ast_node_interactivity = "all" # Show all output, not just last item
pd.set_option('display.max_columns', 999) # Allow viewing of all columns

# %% [markdown]
# ## 2. Combined dataframe
# Create combined dataframe from `base-layer_archival.csv`, and the files in the `ocr_new` folder.

# %%
# Read in base_layer_archival.csv

bob_df = pd.read_csv('../../../base-layers/bob-nelkin-collection/bob-nelkin-collection_item-base-layer_archival.csv')
bob_df.head(1)
# Out:
#                       id                   title creator  contributor  \
# 0  MSS_1002_B001_F11_I01  Recent Litigation Memo     NaN          NaN
#
#    creation_date  sort_date   display_date language type_of_resource format  \
# 0            NaN        NaN  July 11, 1975      NaN              NaN    NaN
#
#   extent  genre                                           abstract subject  \
# 0    NaN    NaN  A PARC internal memo that summarizes recent li...     NaN
#
#    temporal_coverage geographic_coverage  \
# 0                NaN                 NaN
#
#                                         host  \
# 0  Bob Nelkin Collection of ACC-PARC Records
#
#                                 series                 container  \
# 0  I. Administrative Records 1953-1983  box 1, folder 11, Item 1
#
#                   owner                                          depositor  \
# 0  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
#
#     collection_id
# 0  collection.341

# %%
# Read in all the ocr file names and texts as a list of tuples

texts = [(filename, open(filename).read()) for filename in glob.glob("../../../source-data/bob-nelkin-collection/ocr_new/*.txt")]
len(texts)
texts[2] #Random example
# Out:
# 537
# ('../../../source-data/bob-nelkin-collection/ocr_new/pitt_MSS_1002_B004_F17_I13_PDF.txt',
#  '\ufeff\ni I\nA27 Vermont Avenue\nErie, Pennsylvania 16505\nApril 2A, 1973\n\nMs. Helen Wohlgemuth Secretary of Welfare Harrisburg, Pennsylvania\nDear Ms. Wohlgemuth,\nI am a Special Education teacher and h-ave a severely living at Polk State School. Therefore, I feel more than express my great distress caused by your recent firing of superintendent of Polk State School.\nretarded daughter\nQualified to\nDr. JamES McClelland,\n/\n\n\n\nYour ahrupt action indicates to me that you have very little intimate knowledge of severely and profoundly retarded children and adults. There are individuals who require close supervision and partial confinement in a playpen-like enclosure for their safety and the safety of others. This is not cruel and inhumane, it is sensible action taken for safety. Some of the children and adults do reouire rather heavy medication at various times because of severely aggressive hehavior.\nIt is my opinion, and the opinion of various professional persons that I have discussed this matter with, that partial confinement used in conjunction with some medication is far preferable, more humane, and more sensible course of action. This gives aides and teachers the opportunity to work with and try to help the residents.\n\ni $ t\nPlay pens are used by many oarents of young children to keeo them safe and not isolated. Many residents of Polk are still very young children though they are physically mature.\nMy daughter is and has been receiving excellent care at Polk. Dr. McClelland is responsible for a fine program of high Quality care for all the patients in his care. I do not understand how you can possibly charge him with inhumane treatment. He could not Dossiblv have held his position at’ Polk as administrator for so long a time or be so highly respected by his employees, parents of patients, professionals is his field,-and many other people^ if your charges were true.\n\nI believe that you h my sincere wish that you instate Dr. McClelland at gram which is progressive and best interests of its\nave made a very serious error in judgement. It is reconsider this extremely serious decision and re-Polk so that he can continue to administer a pro-\n, thoughtful, residents.\nand has great concern for the welfare')

# %%
# Shorten filenames to match dataframe

texts = [(x[0][56:-8],x[1]) for x in texts]
len(texts)
texts[2]
# Out:
# 537
# ('MSS_1002_B004_F17_I13',
#  '\ufeff\ni I\nA27 Vermont Avenue\nErie, Pennsylvania 16505\nApril 2A, 1973\n\nMs. Helen Wohlgemuth Secretary of Welfare Harrisburg, Pennsylvania\nDear Ms. Wohlgemuth,\nI am a Special Education teacher and h-ave a severely living at Polk State School. Therefore, I feel more than express my great distress caused by your recent firing of superintendent of Polk State School.\nretarded daughter\nQualified to\nDr. JamES McClelland,\n/\n\n\n\nYour ahrupt action indicates to me that you have very little intimate knowledge of severely and profoundly retarded children and adults. There are individuals who require close supervision and partial confinement in a playpen-like enclosure for their safety and the safety of others. This is not cruel and inhumane, it is sensible action taken for safety. Some of the children and adults do reouire rather heavy medication at various times because of severely aggressive hehavior.\nIt is my opinion, and the opinion of various professional persons that I have discussed this matter with, that partial confinement used in conjunction with some medication is far preferable, more humane, and more sensible course of action. This gives aides and teachers the opportunity to work with and try to help the residents.\n\ni $ t\nPlay pens are used by many oarents of young children to keeo them safe and not isolated. Many residents of Polk are still very young children though they are physically mature.\nMy daughter is and has been receiving excellent care at Polk. Dr. McClelland is responsible for a fine program of high Quality care for all the patients in his care. I do not understand how you can possibly charge him with inhumane treatment. He could not Dossiblv have held his position at’ Polk as administrator for so long a time or be so highly respected by his employees, parents of patients, professionals is his field,-and many other people^ if your charges were true.\n\nI believe that you h my sincere wish that you instate Dr. McClelland at gram which is progressive and best interests of its\nave made a very serious error in judgement. It is reconsider this extremely serious decision and re-Polk so that he can continue to administer a pro-\n, thoughtful, residents.\nand has great concern for the welfare')

# %%
# Create dictionary from the tuples

texts_dict = dict(texts)
texts_dict['MSS_1002_B004_F17_I13']
# Out:
# '\ufeff\ni I\nA27 Vermont Avenue\nErie, Pennsylvania 16505\nApril 2A, 1973\n\nMs. Helen Wohlgemuth Secretary of Welfare Harrisburg, Pennsylvania\nDear Ms. Wohlgemuth,\nI am a Special Education teacher and h-ave a severely living at Polk State School. Therefore, I feel more than express my great distress caused by your recent firing of superintendent of Polk State School.\nretarded daughter\nQualified to\nDr. JamES McClelland,\n/\n\n\n\nYour ahrupt action indicates to me that you have very little intimate knowledge of severely and profoundly retarded children and adults. There are individuals who require close supervision and partial confinement in a playpen-like enclosure for their safety and the safety of others. This is not cruel and inhumane, it is sensible action taken for safety. Some of the children and adults do reouire rather heavy medication at various times because of severely aggressive hehavior.\nIt is my opinion, and the opinion of various professional persons that I have discussed this matter with, that partial confinement used in conjunction with some medication is far preferable, more humane, and more sensible course of action. This gives aides and teachers the opportunity to work with and try to help the residents.\n\ni $ t\nPlay pens are used by many oarents of young children to keeo them safe and not isolated. Many residents of Polk are still very young children though they are physically mature.\nMy daughter is and has been receiving excellent care at Polk. Dr. McClelland is responsible for a fine program of high Quality care for all the patients in his care. I do not understand how you can possibly charge him with inhumane treatment. He could not Dossiblv have held his position at’ Polk as administrator for so long a time or be so highly respected by his employees, parents of patients, professionals is his field,-and many other people^ if your charges were true.\n\nI believe that you h my sincere wish that you instate Dr. McClelland at gram which is progressive and best interests of its\nave made a very serious error in judgement. It is reconsider this extremely serious decision and re-Polk so that he can continue to administer a pro-\n, thoughtful, residents.\nand has great concern for the welfare'

# %%
# Map dictionary to the dataframe based on the id column

bob_df['text'] = bob_df.id.map(texts_dict)
bob_df.head()
# Out:
#                       id                                              title  \
# 0  MSS_1002_B001_F11_I01                             Recent Litigation Memo
# 1  MSS_1002_B001_F12_I01            Letter from Peter Polloni to Bob Nelkin
# 2  MSS_1002_B001_F13_I01  Letter to Frank Beal from Families and Friends...
# 3  MSS_1002_B001_F13_I02  Letter from families of patients at Southwest ...
# 4  MSS_1002_B001_F16_I01          ACC-PARC Recent Benefits to Families Memo
#
#   creator  contributor  creation_date  sort_date     display_date language  \
# 0     NaN          NaN            NaN        NaN    July 11, 1975      NaN
# 1     NaN          NaN            NaN        NaN   March 11, 1975      NaN
# 2     NaN          NaN            NaN        NaN  August 19, 1976      NaN
# 3     NaN          NaN            NaN        NaN    July 27, 1976      NaN
# 4     NaN          NaN            NaN        NaN   March 28, 1977      NaN
#
#   type_of_resource format extent  genre  \
# 0              NaN    NaN    NaN    NaN
# 1              NaN    NaN    NaN    NaN
# 2              NaN    NaN    NaN    NaN
# 3              NaN    NaN    NaN    NaN
# 4              NaN    NaN    NaN    NaN
#
#                                             abstract subject  \
# 0  A PARC internal memo that summarizes recent li...     NaN
# 1  A letter from Peter Polloni, executive directo...     NaN
# 2  A letter from Families and Friends of Southwes...     NaN
# 3  A letter requesting Bob Nelkin's advice on adv...     NaN
# 4  Correspondence from Bob Nelkin to Joan Murdoch...     NaN
#
#    temporal_coverage geographic_coverage  \
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4                NaN                 NaN
#
#                                         host  \
# 0  Bob Nelkin Collection of ACC-PARC Records
# 1  Bob Nelkin Collection of ACC-PARC Records
# 2  Bob Nelkin Collection of ACC-PARC Records
# 3  Bob Nelkin Collection of ACC-PARC Records
# 4  Bob Nelkin Collection of ACC-PARC Records
#
#                                 series                 container  \
# 0  I. Administrative Records 1953-1983  box 1, folder 11, Item 1
# 1  I. Administrative Records 1953-1983  box 1, folder 12, Item 1
# 2  I. Administrative Records 1953-1983  box 1, folder 13, Item 1
# 3  I. Administrative Records 1953-1983  box 1, folder 13, Item 2
# 4  I. Administrative Records 1953-1983  box 1, folder 16, Item 1
#
#                   owner                                          depositor  \
# 0  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
# 1  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
# 2  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
# 3  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
# 4  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
#
#     collection_id                                               text
# 0  collection.341  ﻿V\n\nPennsylvania Association for Retarded Ci...
# 1  collection.341  ﻿Pennsylvania Association for Retarded Citizen...
# 2  collection.341  ﻿11\nFAMILIES & FRIENDS OF SOUTHWEST HABILITAT...
# 3  collection.341  ﻿FAMILIES & FRIENDS OF\nSOUTHWEST HABILITATION...
# 4  collection.341  C ommonwealth of Pennsylvania\n\nDepartment of...

# %% [markdown]
# ## 3. Missing data
#
# Check columns to see if anything is needed or if any columns are unnecessary

# %%
[(x,len(bob_df.loc[~bob_df[x].isnull()])) for x in bob_df.columns]
# Out:
# [('id', 542),
#  ('title', 542),
#  ('creator', 1),
#  ('contributor', 0),
#  ('creation_date', 0),
#  ('sort_date', 0),
#  ('display_date', 541),
#  ('language', 1),
#  ('type_of_resource', 1),
#  ('format', 1),
#  ('extent', 1),
#  ('genre', 0),
#  ('abstract', 540),
#  ('subject', 1),
#  ('temporal_coverage', 0),
#  ('geographic_coverage', 1),
#  ('host', 541),
#  ('series', 541),
#  ('container', 541),
#  ('owner', 541),
#  ('depositor', 542),
#  ('collection_id', 542),
#  ('text', 536)]

# %% [markdown]
# Look at the ones with 1 non-null to see what these are.

# %%
# creator column (are any non-null?)

bob_df.loc[~bob_df.creator.isnull()]

# Only one file, the guide, has a creator
# Out:
#                  id                                              title  \
# 541  US-QQS-MSS1002  Guide to the Bob Nelkin Collection of ACC-PARC...
#
#          creator  contributor  creation_date  sort_date display_date language  \
# 541  Nelkin, Bob          NaN            NaN        NaN          NaN  English
#
#     type_of_resource format                   extent  genre  \
# 541             text  print  4.5 linear feet + shelf    NaN
#
#                                               abstract  \
# 541  The Bob Nelkin Collection of ACC-PARC records ...
#
#                                                subject  temporal_coverage  \
# 541  Social service|||Social welfare|||Disability a...                NaN
#
#            geographic_coverage host series container owner  \
# 541  Pennsylvania|||Pittsburgh  NaN    NaN       NaN   NaN
#
#                                           depositor   collection_id text
# 541  Detre Library & Archives, Heinz History Center  collection.341  NaN

# %%
# Remove this guide from the dataframe to keep only actual collection texts

len(bob_df)
bob_df = bob_df.loc[bob_df.id != 'US-QQS-MSS1002']
len(bob_df)
# Out:
# 542
# 541

# %%
# Check null values again

[(x,len(bob_df.loc[~bob_df[x].isnull()])) for x in bob_df.columns]
# Out:
# [('id', 541),
#  ('title', 541),
#  ('creator', 0),
#  ('contributor', 0),
#  ('creation_date', 0),
#  ('sort_date', 0),
#  ('display_date', 541),
#  ('language', 0),
#  ('type_of_resource', 0),
#  ('format', 0),
#  ('extent', 0),
#  ('genre', 0),
#  ('abstract', 539),
#  ('subject', 0),
#  ('temporal_coverage', 0),
#  ('geographic_coverage', 0),
#  ('host', 541),
#  ('series', 541),
#  ('container', 541),
#  ('owner', 541),
#  ('depositor', 541),
#  ('collection_id', 541),
#  ('text', 536)]

# %% [markdown]
# Everything either has a a value or is completely empty except for 'abstract'

# %%
# check missing abstracts

bob_df.loc[bob_df.abstract.isnull()]
# Out:
#                        id                                              title  \
# 50  MSS_1002_B001_F65_I12      Letter from Mr. W. to Dr. James R. McClelland
# 51  MSS_1002_B001_F65_I13  Reforming the State Schools and Interim Care C...
#
#    creator  contributor  creation_date  sort_date        display_date  \
# 50     NaN          NaN            NaN        NaN  September 28, 1972
# 51     NaN          NaN            NaN        NaN   November 28, 1972
#
#    language type_of_resource format extent  genre abstract subject  \
# 50      NaN              NaN    NaN    NaN    NaN      NaN     NaN
# 51      NaN              NaN    NaN    NaN    NaN      NaN     NaN
#
#     temporal_coverage geographic_coverage  \
# 50                NaN                 NaN
# 51                NaN                 NaN
#
#                                          host  \
# 50  Bob Nelkin Collection of ACC-PARC Records
# 51  Bob Nelkin Collection of ACC-PARC Records
#
#                                                series  \
# 50  II. State School and Hospital (SSH) and Interi...
# 51  II. State School and Hospital (SSH) and Interi...
#
#                     container                 owner  \
# 50  box 1, Folder 65, Item 12  Heinz History Center
# 51  box 1, Folder 65, Item 13  Heinz History Center
#
#                                             depositor   collection_id  \
# 50  Detre Library & Archives, Heinz History\n     ...  collection.341
# 51  Detre Library & Archives, Heinz History\n     ...  collection.341
#
#                                                  text
# 50                                                  ﻿
# 51  ﻿REFORMING OF THE STATE SCHOOLS AND HOSPITALS ...

# %%
# Write new temporary abstracts (can be used if desired by the collection owners)

new_abstract1 = "A letter from Mr. W. to Dr. James R. McClelland expressing his opposition to the rule prohibiting the use of phone commmunication between patiens and parents."
new_abstract2 = "A statement from the 'Reforming the State Schools and Interim Care Committee' Statement' providing an update on the committee and the challenges they face."

# %%
# Add the new abstracts to the dataframe

bob_df.loc[bob_df.id == 'MSS_1002_B001_F65_I12','abstract'] = new_abstract1
bob_df.loc[bob_df.id == 'MSS_1002_B001_F65_I13','abstract'] = new_abstract2

# %%
# Delete empty columns

cols = [x for x in bob_df.columns if len(bob_df.loc[~bob_df[x].isnull()])!=0]
bob_df = bob_df[cols]
bob_df.head()
# Out:
#                       id                                              title  \
# 0  MSS_1002_B001_F11_I01                             Recent Litigation Memo
# 1  MSS_1002_B001_F12_I01            Letter from Peter Polloni to Bob Nelkin
# 2  MSS_1002_B001_F13_I01  Letter to Frank Beal from Families and Friends...
# 3  MSS_1002_B001_F13_I02  Letter from families of patients at Southwest ...
# 4  MSS_1002_B001_F16_I01          ACC-PARC Recent Benefits to Families Memo
#
#       display_date                                           abstract  \
# 0    July 11, 1975  A PARC internal memo that summarizes recent li...
# 1   March 11, 1975  A letter from Peter Polloni, executive directo...
# 2  August 19, 1976  A letter from Families and Friends of Southwes...
# 3    July 27, 1976  A letter requesting Bob Nelkin's advice on adv...
# 4   March 28, 1977  Correspondence from Bob Nelkin to Joan Murdoch...
#
#                                         host  \
# 0  Bob Nelkin Collection of ACC-PARC Records
# 1  Bob Nelkin Collection of ACC-PARC Records
# 2  Bob Nelkin Collection of ACC-PARC Records
# 3  Bob Nelkin Collection of ACC-PARC Records
# 4  Bob Nelkin Collection of ACC-PARC Records
#
#                                 series                 container  \
# 0  I. Administrative Records 1953-1983  box 1, folder 11, Item 1
# 1  I. Administrative Records 1953-1983  box 1, folder 12, Item 1
# 2  I. Administrative Records 1953-1983  box 1, folder 13, Item 1
# 3  I. Administrative Records 1953-1983  box 1, folder 13, Item 2
# 4  I. Administrative Records 1953-1983  box 1, folder 16, Item 1
#
#                   owner                                          depositor  \
# 0  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
# 1  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
# 2  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
# 3  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
# 4  Heinz History Center  Detre Library & Archives, Heinz History\n     ...
#
#     collection_id                                               text
# 0  collection.341  ﻿V\n\nPennsylvania Association for Retarded Ci...
# 1  collection.341  ﻿Pennsylvania Association for Retarded Citizen...
# 2  collection.341  ﻿11\nFAMILIES & FRIENDS OF SOUTHWEST HABILITAT...
# 3  collection.341  ﻿FAMILIES & FRIENDS OF\nSOUTHWEST HABILITATION...
# 4  collection.341  C ommonwealth of Pennsylvania\n\nDepartment of...

# %%
# text - check texts that are just an empty string or nan

len(bob_df.loc[bob_df.text == ''])
bob_df.loc[bob_df.text == ''].head()

len(bob_df.loc[bob_df.text.isnull()])
bob_df.loc[bob_df.text.isnull()].head()
# Out:
# 0
# Empty DataFrame
# Columns: [id, title, display_date, abstract, host, series, container, owner, depositor, collection_id, text]
# Index: []
# 5
#                         id                                     title  \
# 532  MSS_1002_B004_F56_I01    Highland Park Center Restraining Chair
# 533  MSS_1002_B004_F56_I02      Highland Park Center Resident Helmet
# 534  MSS_1002_B004_F56_I03  Highland Park Center Resident Helmet (2)
# 535  MSS_1002_B004_F56_I04         Highland Park Center Straitjacket
# 536  MSS_1002_B004_F56_I05          Highland Park Center Cattle Prod
#
#     display_date                                           abstract  \
# 532  August 1983  An image of a chair with restraints used on in...
# 533  August 1983  An image of a helmet used on an individual wit...
# 534  August 1983  An image of a helmet used on an individual wit...
# 535  August 1983  An image of a straitjacket used on individuals...
# 536  August 1983  An image of a cattle prod used to shock indivi...
#
#                                           host  \
# 532  Bob Nelkin Collection of ACC-PARC Records
# 533  Bob Nelkin Collection of ACC-PARC Records
# 534  Bob Nelkin Collection of ACC-PARC Records
# 535  Bob Nelkin Collection of ACC-PARC Records
# 536  Bob Nelkin Collection of ACC-PARC Records
#
#                                                 series  \
# 532  II. State School and Hospital (SSH) and Interi...
# 533  II. State School and Hospital (SSH) and Interi...
# 534  II. State School and Hospital (SSH) and Interi...
# 535  II. State School and Hospital (SSH) and Interi...
# 536  II. State School and Hospital (SSH) and Interi...
#
#                     container                 owner  \
# 532  box 4, Folder 56, Item 1  Heinz History Center
# 533  box 4, Folder 56, Item 2  Heinz History Center
# 534  box 4, Folder 56, Item 3  Heinz History Center
# 535  box 4, Folder 56, Item 4  Heinz History Center
# 536  box 4, Folder 56, Item 5  Heinz History Center
#
#                                              depositor   collection_id text
# 532  Detre Library & Archives, Heinz History\n     ...  collection.341  NaN
# 533  Detre Library & Archives, Heinz History\n     ...  collection.341  NaN
# 534  Detre Library & Archives, Heinz History\n     ...  collection.341  NaN
# 535  Detre Library & Archives, Heinz History\n     ...  collection.341  NaN
# 536  Detre Library & Archives, Heinz History\n     ...  collection.341  NaN

# %% [markdown]
# These five are all photos.

# %% [markdown]
# #### Check language
#
# Do not run multiple times as Google API has daily limit of queries.

# %%
# Use textblob (API for Google translate) - there is a max number of requests per day so do not run unless needed

def find_lang(text):
    return TextBlob(text).detect_language()

find_lang("This is a test")
# Out:
# 'en'

# %%
# Apply function to title column (since text columns sometimes blank)

bob_df['language'] = bob_df.title.apply(find_lang)

# %%
bob_df.language.value_counts()
# Out:
# en    536
# de      3
# fy      1
# no      1
# Name: language, dtype: int64

# %%
# I can see why these were mistagged 

bob_df.loc[bob_df.language == 'de']
bob_df.loc[bob_df.language == 'fy']
bob_df.loc[bob_df.language == 'no']
# Out:
#                         id                                             title  \
# 260  MSS_1002_B004_F17_I10      Letter from Mrs. Besser to Helene Wohlgemuth
# 334  MSS_1002_B004_F20_I01  Letter from Marjorie Felder to Helene Wohlgemuth
# 360  MSS_1002_B004_F20_I27   Note from Barbara Fruchter to Helene Wohlgemuth
#
#        display_date                                           abstract  \
# 260        May 1973  A letter from Mrs. Besser, a parent of a child...
# 334  April 23, 1973  A letter from Marjorie Felder to Secretary Hel...
# 360  April 18, 1973  A brief note from Barbara Fruchter to Secretar...
#
#                                           host  \
# 260  Bob Nelkin Collection of ACC-PARC Records
# 334  Bob Nelkin Collection of ACC-PARC Records
# 360  Bob Nelkin Collection of ACC-PARC Records
#
#                                                 series  \
# 260  II. State School and Hospital (SSH) and Interi...
# 334  II. State School and Hospital (SSH) and Interi...
# 360  II. State School and Hospital (SSH) and Interi...
#
#                      container                 owner  \
# 260  box 4, Folder 17, Item 10  Heinz History Center
# 334   box 4, Folder 20, Item 1  Heinz History Center
# 360  box 4, Folder 20, Item 27  Heinz History Center
#
#                                              depositor   collection_id  \
# 260  Detre Library & Archives, Heinz History\n     ...  collection.341
# 334  Detre Library & Archives, Heinz History\n     ...  collection.341
# 360  Detre Library & Archives, Heinz History\n     ...  collection.341
#
#                                                   text language
# 260  ﻿\n\n\n\n\n-v:\nt'\nT\n£\n\n5\n1\nv<\n\n.3 .\n...       de
# 334  ﻿\n\n4\n\n5F\nt-\n>*\n.><\n\n/\n!\n/\nV? c\nf ...       de
# 360  ﻿\n*4t\n>\n»(<\n•\n\nf •\n-,T\n... ,„,,,\n\nc\...       de
#                         id                                            title  \
# 270  MSS_1002_B004_F17_I20  Letter from David Ferleger to Helene Wohlgemuth
#
#        display_date                                           abstract  \
# 270  April 26, 1973  A letter from David Ferleger of the Mental Pat...
#
#                                           host  \
# 270  Bob Nelkin Collection of ACC-PARC Records
#
#                                                 series  \
# 270  II. State School and Hospital (SSH) and Interi...
#
#                      container                 owner  \
# 270  box 4, Folder 17, Item 20  Heinz History Center
#
#                                              depositor   collection_id  \
# 270  Detre Library & Archives, Heinz History\n     ...  collection.341
#
#                                                   text language
# 270  ﻿MENTAL PATIENT CIVIL LIBERTIES PROJECT\n121 S...       fy
#                         id                                           title  \
# 265  MSS_1002_B004_F17_I15  Letter from Eleanor Etter to Helene Wohlgemuth
#
#        display_date                                           abstract  \
# 265  April 27, 1973  A letter from Eleanor Etter to Helene Wohlgemu...
#
#                                           host  \
# 265  Bob Nelkin Collection of ACC-PARC Records
#
#                                                 series  \
# 265  II. State School and Hospital (SSH) and Interi...
#
#                      container                 owner  \
# 265  box 4, Folder 17, Item 15  Heinz History Center
#
#                                              depositor   collection_id  \
# 265  Detre Library & Archives, Heinz History\n     ...  collection.341
#
#                                                   text language
# 265  ﻿\n# • •\n\n\ni\n> H / x\n• f K\nApril 27, 197...       no

# %%
# Change all language column to 'English'

bob_df.language = 'English'

# %% [markdown]
# ## 4. Standardization
#
# Most columns and values are already standardized and consistent. One option would be to create a new column for 'text' type, e.g., article, press release, etc. based on the titles. However, a number of these are not clear from the title alone.

# %%
# Fix string so all on one line

bob_df.depositor = 'Detre Library & Archives, Heinz History Center'

# %% [markdown]
# ## 5. Save dataframe

# %%
# Pickle dataframe

joblib.dump(bob_df,'bob_df_pre-processed.pkl')
# Out:
# ['bob_df_pre-processed.pkl']

# %%
bob_df.head()
# Out:
#                       id                                              title  \
# 0  MSS_1002_B001_F11_I01                             Recent Litigation Memo
# 1  MSS_1002_B001_F12_I01            Letter from Peter Polloni to Bob Nelkin
# 2  MSS_1002_B001_F13_I01  Letter to Frank Beal from Families and Friends...
# 3  MSS_1002_B001_F13_I02  Letter from families of patients at Southwest ...
# 4  MSS_1002_B001_F16_I01          ACC-PARC Recent Benefits to Families Memo
#
#       display_date                                           abstract  \
# 0    July 11, 1975  A PARC internal memo that summarizes recent li...
# 1   March 11, 1975  A letter from Peter Polloni, executive directo...
# 2  August 19, 1976  A letter from Families and Friends of Southwes...
# 3    July 27, 1976  A letter requesting Bob Nelkin's advice on adv...
# 4   March 28, 1977  Correspondence from Bob Nelkin to Joan Murdoch...
#
#                                         host  \
# 0  Bob Nelkin Collection of ACC-PARC Records
# 1  Bob Nelkin Collection of ACC-PARC Records
# 2  Bob Nelkin Collection of ACC-PARC Records
# 3  Bob Nelkin Collection of ACC-PARC Records
# 4  Bob Nelkin Collection of ACC-PARC Records
#
#                                 series                 container  \
# 0  I. Administrative Records 1953-1983  box 1, folder 11, Item 1
# 1  I. Administrative Records 1953-1983  box 1, folder 12, Item 1
# 2  I. Administrative Records 1953-1983  box 1, folder 13, Item 1
# 3  I. Administrative Records 1953-1983  box 1, folder 13, Item 2
# 4  I. Administrative Records 1953-1983  box 1, folder 16, Item 1
#
#                   owner                                       depositor  \
# 0  Heinz History Center  Detre Library & Archives, Heinz History Center
# 1  Heinz History Center  Detre Library & Archives, Heinz History Center
# 2  Heinz History Center  Detre Library & Archives, Heinz History Center
# 3  Heinz History Center  Detre Library & Archives, Heinz History Center
# 4  Heinz History Center  Detre Library & Archives, Heinz History Center
#
#     collection_id                                               text language
# 0  collection.341  ﻿V\n\nPennsylvania Association for Retarded Ci...  English
# 1  collection.341  ﻿Pennsylvania Association for Retarded Citizen...  English
# 2  collection.341  ﻿11\nFAMILIES & FRIENDS OF SOUTHWEST HABILITAT...  English
# 3  collection.341  ﻿FAMILIES & FRIENDS OF\nSOUTHWEST HABILITATION...  English
# 4  collection.341  C ommonwealth of Pennsylvania\n\nDepartment of...  English

# %% [markdown]
# [Back to top](#Bob-Nelkin-Collection---Pre-processing)
